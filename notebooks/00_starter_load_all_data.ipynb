# %% [markdown]
# # Starter Notebook — Buku Ajar BI
#
# **Notebook ini akan membantu Anda load semua dataset yang dibahas di buku, langsung dari GitHub tanpa download manual.**
#
# Cara pakai: jalankan setiap cell dari atas ke bawah dengan `Shift+Enter`.
#
# Penulis: Raden Johnny Hadi Raharjo — UPN Veteran Jawa Timur, 2026

# %% [markdown]
# ## 1. Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 120)

print('Pandas version:', pd.__version__)
print('Setup OK')

# %% [markdown]
# ## 2. Load Dataset Roti Nusantara (Bab 1-14)

# %%
BASE = 'https://raw.githubusercontent.com/Tjakra12/buku-ajar-bi-companion/main/dataset-master-roti-nusantara'

df_customers = pd.read_csv(f'{BASE}/customers.csv')
df_products = pd.read_csv(f'{BASE}/products.csv')
df_tx_clean = pd.read_csv(f'{BASE}/transactions_clean.csv')
df_tx_messy = pd.read_csv(f'{BASE}/transactions_messy.csv')
df_finance = pd.read_csv(f'{BASE}/finance_monthly.csv')
df_cashflow = pd.read_csv(f'{BASE}/finance_cashflow_monthly.csv')
df_hr = pd.read_csv(f'{BASE}/hr_employees.csv')
df_survey = pd.read_csv(f'{BASE}/hr_engagement_survey.csv')
df_marketing = pd.read_csv(f'{BASE}/marketing_campaigns.csv')
df_operations = pd.read_csv(f'{BASE}/operation_daily.csv')
df_reviews = pd.read_csv(f'{BASE}/customer_reviews.csv')

print('All Roti Nusantara datasets loaded')
print(f'transactions_clean: {len(df_tx_clean):,} rows')
print(f'transactions_messy: {len(df_tx_messy):,} rows')
print(f'operation_daily:    {len(df_operations):,} rows')

# %% [markdown]
# ## 3. Sneak Peek

# %%
df_tx_clean.head()

# %%
df_tx_clean.describe()

# %% [markdown]
# ## 4. Load Dataset Capstone NSI (Bab 15)

# %%
CAPSTONE = 'https://raw.githubusercontent.com/Tjakra12/buku-ajar-bi-companion/main/dataset-capstone-nsi'

df_store = pd.read_csv(f'{CAPSTONE}/01_store_master.csv')
df_sku = pd.read_csv(f'{CAPSTONE}/02_sku_master.csv')
df_pos = pd.read_csv(f'{CAPSTONE}/03_pos_transactions_q4_2025.csv')
df_inventory = pd.read_csv(f'{CAPSTONE}/04_inventory_snapshot.csv')
df_hr_nsi = pd.read_csv(f'{CAPSTONE}/05_hr_employees.csv')
df_complaints = pd.read_csv(f'{CAPSTONE}/06_customer_complaints.csv')
df_mkt_nsi = pd.read_csv(f'{CAPSTONE}/07_marketing_campaigns.csv')
df_gl = pd.read_csv(f'{CAPSTONE}/08_financial_gl_monthly.csv')
df_nps = pd.read_csv(f'{CAPSTONE}/09_nps_survey.csv')

print('All NSI Capstone datasets loaded')
print(f'POS transactions Q4: {len(df_pos):,} rows')
print(f'Inventory snapshots: {len(df_inventory):,} rows')
print(f'NPS responses:       {len(df_nps):,} rows')

# %% [markdown]
# ## 5. Sekarang Anda Siap!
#
# Buka buku ajar di Bab 1 dan mulai eksperimen. Setiap kali bab menyebutkan dataset, file-nya sudah ter-load di notebook ini sebagai DataFrame.
#
# Selamat belajar!
